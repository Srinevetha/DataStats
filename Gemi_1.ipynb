# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinevetha/DataStats/blob/master/Gemi_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project qwiklabs-gcp-03-770d1d1bc897
SELECT * FROM `bigquery-public-data.ml_datasets.penguins` #this example uses a penguin public dataset. Learn more here: https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=ml_datasets&t=penguins&page=table&_ga=2.251359750.1031997792.1692116300-1119797950.1692116300
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#                                        species     island  culmen_length_mm  \
# 0          Adelie Penguin (Pygoscelis adeliae)      Dream              36.6
# 1          Adelie Penguin (Pygoscelis adeliae)      Dream              39.8
# 2          Adelie Penguin (Pygoscelis adeliae)      Dream              40.9
# 3    Chinstrap penguin (Pygoscelis antarctica)      Dream              46.5
# 4          Adelie Penguin (Pygoscelis adeliae)      Dream              37.3
# ..                                         ...        ...               ...
# 339        Adelie Penguin (Pygoscelis adeliae)  Torgersen              38.8
# 340        Adelie Penguin (Pygoscelis adeliae)  Torgersen              40.9
# 341        Adelie Penguin (Pygoscelis adeliae)  Torgersen              39.0
# 342        Adelie Penguin (Pygoscelis adeliae)  Torgersen              40.6
# 343        Adelie Penguin (Pygoscelis adeliae)  Torgersen              37.3
#
#      culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 0               18.4              184.0       3475.0  FEMALE
# 1               19.1              184.0       4650.0    MALE
# 2               18.9              184.0       3900.0    MALE
# 3               17.9              192.0       3500.0  FEMALE
# 4               16.8              192.0       3000.0  FEMALE
# ..               ...                ...          ...     ...
# 339             17.6              191.0       3275.0  FEMALE
# 340             16.8              191.0       3700.0  FEMALE
# 341             17.1              191.0       3050.0  FEMALE
# 342             19.0              199.0       4000.0    MALE
# 343             20.5              199.0       3775.0    MALE
#
# [344 rows x 7 columns]

# %% [markdown]
# # Example 2: Query a table with BigQuery DataFrames

# %%
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "us" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "qwiklabs-gcp-03-770d1d1bc897" #this variable is set based on the dataset you chose to query
# Out:
# <ipython-input-3-d6f1cdfa2ab4>:8: UnknownLocationWarning: The location 'us' is set to an unknown value. Did you mean 'US'?
#   bf.options.bigquery.location = "us" #this variable is set based on the dataset you chose to query

# %%
# This example uses a penguin public dataset.
# Learn more here: https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=ml_datasets&t=penguins&page=table&_ga=2.251359750.1031997792.1692116300-1119797950.1692116300
df = bf.read_gbq("bigquery-public-data.ml_datasets.penguins")

# %%
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# Query job 8dd21d97-c144-4af4-b037-c2e2778714a8 is DONE. 28.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:8dd21d97-c144-4af4-b037-c2e2778714a8&page=queryresults">Open Job</a>
# Query job 554eead7-5f47-4c62-a082-82a2ae4e9749 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:554eead7-5f47-4c62-a082-82a2ae4e9749&page=queryresults">Open Job</a>
# Query job 73342e94-dc5d-49ae-8ab9-771553c824ee is DONE. 2.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:73342e94-dc5d-49ae-8ab9-771553c824ee&page=queryresults">Open Job</a>
#                                       species     island  culmen_length_mm  \
# 0           Gentoo penguin (Pygoscelis papua)     Biscoe              50.5
# 1           Gentoo penguin (Pygoscelis papua)     Biscoe              45.1
# 2         Adelie Penguin (Pygoscelis adeliae)  Torgersen              41.4
# 3         Adelie Penguin (Pygoscelis adeliae)  Torgersen              38.6
# 4           Gentoo penguin (Pygoscelis papua)     Biscoe              46.5
# 5         Adelie Penguin (Pygoscelis adeliae)     Biscoe              35.0
# 6         Adelie Penguin (Pygoscelis adeliae)      Dream              37.5
# 7           Gentoo penguin (Pygoscelis papua)     Biscoe              42.0
# 8           Gentoo penguin (Pygoscelis papua)     Biscoe              48.5
# 9         Adelie Penguin (Pygoscelis adeliae)  Torgersen              45.8
# 10  Chinstrap penguin (Pygoscelis antarctica)      Dream              49.0
# 11        Adelie Penguin (Pygoscelis adeliae)  Torgersen              35.9
# 12          Gentoo penguin (Pygoscelis papua)     Biscoe              51.1
# 13          Gentoo penguin (Pygoscelis papua)     Biscoe              42.6
# 14  Chinstrap penguin (Pygoscelis antarctica)      Dream              46.9
# 15        Adelie Penguin (Pygoscelis adeliae)      Dream              41.1
# 16          Gentoo penguin (Pygoscelis papua)     Biscoe              49.2
# 17        Adelie Penguin (Pygoscelis adeliae)     Biscoe              38.1
# 18          Gentoo penguin (Pygoscelis papua)     Biscoe              51.3
# 19          Gentoo penguin (Pygoscelis papua)     Biscoe              43.6
#
#     culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 0              15.9              225.0       5400.0    MALE
# 1              14.5              215.0       5000.0  FEMALE
# 2              18.5              202.0       3875.0    MALE
# 3              17.0              188.0       2900.0  FEMALE
# 4              14.8              217.0       5200.0  FEMALE
# 5              17.9              192.0       3725.0  FEMALE
# 6              18.9              179.0       2975.0    <NA>
# 7              13.5              210.0       4150.0  FEMALE
# 8              14.1              220.0       5300.0    MALE
# 9              18.9              197.0       4150.0    MALE
# 10             19.6              212.0       4300.0    MALE
# 11             16.6              190.0       3050.0  FEMALE
# 12             16.3              220.0       6000.0    MALE
# 13             13.7              213.0       4950.0  FEMALE
# 14             16.6              192.0       2700.0  FEMALE
# 15             17.5              190.0       3900.0    MALE
# 16             15.2              221.0       6300.0    MALE
# 17             16.5              198.0       3825.0  FEMALE
# 18             14.2              218.0       5300.0    MALE
# 19             13.9              217.0       4900.0  FEMALE
#
# [20 rows x 7 columns]

# %%
from google.cloud import bigquery
from google.cloud import aiplatform
import bigframes.pandas as bpd
import pandas as pd
from vertexai.language_models._language_models import TextGenerationModel
from bigframes.ml.cluster import KMeans
from bigframes.ml.model_selection import train_test_split

# %%
project_id = 'qwiklabs-gcp-03-770d1d1bc897'
dataset_name = "ecommerce"
model_name = "customer_segmentation_model"
table_name = "customer_stats"
location = "us-central1"
client = bigquery.Client(project=project_id)
aiplatform.init(project=project_id, location=location)

# %%
# %%bigquery
# CREATE OR REPLACE TABLE ecommerce.customer_stats AS
# SELECT
#   user_id,
#   DATE_DIFF(CURRENT_DATE(), CAST(MAX(order_created_date) AS DATE), day) AS days_since_last_order, ---RECENCY
#   COUNT(order_id) AS count_orders, --FREQUENCY
#   AVG(sale_price) AS average_spend --MONETARY
#   FROM (
#       SELECT
#         user_id,
#         order_id,
#         sale_price,
#         created_at AS order_created_date
#         FROM `bigquery-public-data.thelook_ecommerce.order_items`
#         WHERE
#         created_at
#             BETWEEN '2022-01-01' AND '2023-01-01'
#   )
# GROUP BY user_id;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# prompt: Convert the table ecommerce.customer_stats to a BigQuery DataFrames dataframe and show the top 10 records


customer_df = bf.read_gbq("qwiklabs-gcp-03-770d1d1bc897.ecommerce.customer_stats")
customer_df.head(10)
# Out:
# Query job 4df9120d-e5d8-44f9-90a9-54d1b3832c0c is DONE. 637.4 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:4df9120d-e5d8-44f9-90a9-54d1b3832c0c&page=queryresults">Open Job</a>
# Query job 61a35cf1-cae4-4b59-991f-f1fa7580f2c7 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:61a35cf1-cae4-4b59-991f-f1fa7580f2c7&page=queryresults">Open Job</a>
# Query job c287ba9a-9c4b-4a19-95da-2c5836026353 is DONE. 480 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:c287ba9a-9c4b-4a19-95da-2c5836026353&page=queryresults">Open Job</a>
#    user_id  days_since_last_order  count_orders  average_spend
# 0    26243                    841             1           36.0
# 1    91111                    562             3      39.333333
# 2    80134                    706             1           30.0
# 3    48185                    650             1          11.22
# 4      885                    742             1     111.989998
# 5    34296                    886             4        62.3575
# 6     9454                    693             1            6.5
# 7    12519                    700             4          57.77
# 8    91179                    633             1      39.990002
# 9    55783                    578             7      82.275714
#
# [10 rows x 4 columns]

# %%
# prompt: 1. Split df into test and training data for a K-means clustering algorithm store these as df_test_ and df_train. 2. Create a K-means cluster model using bigframes.ml.cluster KMeans with 5 clusters. 3. Save the model to BigQuery in a model called ecommerce.model_name using the to_gbq method.

'''df_train, df_test = train_test_split(customer_df, test_size=0.2, random_state=42)
kmeans = KMeans(k=5, random_state=42)
model = kmeans.fit(df_train)
model.to_gbq(model_name=model_name,
           project_id=project_id,
           location=location,
           )'''
# Out:
# 'df_train, df_test = train_test_split(customer_df, test_size=0.2, random_state=42)\nkmeans = KMeans(k=5, random_state=42)\nmodel = kmeans.fit(df_train)\nmodel.to_gbq(model_name=model_name,\n           project_id=project_id,\n           location=location,\n           )'

# %%
#prompt: 1. Split df into test and training data for a K-means clustering algorithm store these as df_test_ and df_train. 2. Create a K-means cluster model using bigframes.ml.cluster KMeans with 5 clusters. 3. Save the model to BigQuery in a model called ecommerce.model_name using the to_gbq method.

df_train, df_test = train_test_split(df, test_size=0.2,  random_state=42)
model = KMeans(n_clusters=5)
model.fit(df_train)
model.to_gbq(f"{project_id}.{dataset_name}.{model_name}")
# Out:
# Query job 423a32f6-4371-4bc2-b64d-539fb2a054f0 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:423a32f6-4371-4bc2-b64d-539fb2a054f0&page=queryresults">Open Job</a>
# Query job b35573f7-d13e-4249-bb0f-0bbe38aeacad is DONE. 28.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:b35573f7-d13e-4249-bb0f-0bbe38aeacad&page=queryresults">Open Job</a>
# Query job 5b17df11-e841-490a-9cc0-f8f798cd19e0 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:5b17df11-e841-490a-9cc0-f8f798cd19e0&page=queryresults">Open Job</a>
# Copy job c935c9cb-ad81-4b0d-bf5e-9373ab9e584c is DONE. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:c935c9cb-ad81-4b0d-bf5e-9373ab9e584c&page=queryresults">Open Job</a>
# KMeans(distance_type='EUCLIDEAN', init='KMEANS_PLUS_PLUS', n_clusters=5)

# %%
#qwiklabs-gcp-03-770d1d1bc897.ecommerce.customer_stats

# %%
# prompt: 1. Call the K-means prediction model on the df dataframe, and store the results as predictions_df and show the first 10 records.
# prompt: 1. Call the K-means prediction model on the df dataframe, and store the results as predictions_df and show the first 10 records.

predictions_df = model.predict(df)
predictions_df.head(10)
# Out:
# Query job 9d518dcf-e980-4d7e-8891-aa6f106e81c8 is DONE. 30.1 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:9d518dcf-e980-4d7e-8891-aa6f106e81c8&page=queryresults">Open Job</a>
# Query job da44ec67-fc56-44ad-bf2e-7e3ae2367dc8 is DONE. 62.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:da44ec67-fc56-44ad-bf2e-7e3ae2367dc8&page=queryresults">Open Job</a>
# Query job 22f289cd-6562-40ec-84c6-f9f6fd21e50b is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:22f289cd-6562-40ec-84c6-f9f6fd21e50b&page=queryresults">Open Job</a>
# Query job ed9d949b-8084-4f99-87c4-04c3fd49e251 is DONE. 1.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:ed9d949b-8084-4f99-87c4-04c3fd49e251&page=queryresults">Open Job</a>
#    CENTROID_ID                         NEAREST_CENTROIDS_DISTANCE  \
# 0            3  [{'CENTROID_ID': 3, 'DISTANCE': 0.366734437469...
# 1            4  [{'CENTROID_ID': 4, 'DISTANCE': 0.444748439339...
# 2            2  [{'CENTROID_ID': 2, 'DISTANCE': 1.437399570956...
# 3            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.088371772681...
# 4            4  [{'CENTROID_ID': 4, 'DISTANCE': 0.753915336265...
# 5            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.193884383458...
# 6            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.811468871650...
# 7            4  [{'CENTROID_ID': 4, 'DISTANCE': 1.035959788347...
# 8            1  [{'CENTROID_ID': 1, 'DISTANCE': 0.675342653565...
# 9            2  [{'CENTROID_ID': 2, 'DISTANCE': 1.280205429269...
#
#                                species     island  culmen_length_mm  \
# 0    Gentoo penguin (Pygoscelis papua)     Biscoe              50.5
# 1    Gentoo penguin (Pygoscelis papua)     Biscoe              45.1
# 2  Adelie Penguin (Pygoscelis adeliae)  Torgersen              41.4
# 3  Adelie Penguin (Pygoscelis adeliae)  Torgersen              38.6
# 4    Gentoo penguin (Pygoscelis papua)     Biscoe              46.5
# 5  Adelie Penguin (Pygoscelis adeliae)     Biscoe              35.0
# 6  Adelie Penguin (Pygoscelis adeliae)      Dream              37.5
# 7    Gentoo penguin (Pygoscelis papua)     Biscoe              42.0
# 8    Gentoo penguin (Pygoscelis papua)     Biscoe              48.5
# 9  Adelie Penguin (Pygoscelis adeliae)  Torgersen              45.8
#
#    culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 0             15.9              225.0       5400.0    MALE
# 1             14.5              215.0       5000.0  FEMALE
# 2             18.5              202.0       3875.0    MALE
# 3             17.0              188.0       2900.0  FEMALE
# 4             14.8              217.0       5200.0  FEMALE
# 5             17.9              192.0       3725.0  FEMALE
# 6             18.9              179.0       2975.0    <NA>
# 7             13.5              210.0       4150.0  FEMALE
# 8             14.1              220.0       5300.0    MALE
# 9             18.9              197.0       4150.0    MALE
#
# [10 rows x 9 columns]

# %%
# prompt: Convert the table ecommerce.customer_stats to a BigQuery DataFrames dataframe and show the top 10 records


customer_df = bf.read_gbq("qwiklabs-gcp-03-770d1d1bc897.ecommerce.customer_stats")
customer_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3553: UserWarning: Reading cached table from 2024-06-27 09:56:42.035987+00:00 to avoid incompatibilies with previous reads of this table. To read the latest version, set `use_cache=False` or close the current session with Session.close() or bigframes.pandas.close_session().
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Query job 2e99f374-a874-4c6d-bbce-20042fc61a55 is DONE. 637.4 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:2e99f374-a874-4c6d-bbce-20042fc61a55&page=queryresults">Open Job</a>
# Query job bb313b01-7723-48c0-9731-6c4fdd568392 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:bb313b01-7723-48c0-9731-6c4fdd568392&page=queryresults">Open Job</a>
# Query job 0c61883e-e2d3-4562-8382-b04c7ca954a8 is DONE. 480 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:0c61883e-e2d3-4562-8382-b04c7ca954a8&page=queryresults">Open Job</a>
#    user_id  days_since_last_order  count_orders  average_spend
# 0    26243                    841             1           36.0
# 1    91111                    562             3      39.333333
# 2    80134                    706             1           30.0
# 3    48185                    650             1          11.22
# 4      885                    742             1     111.989998
# 5    34296                    886             4        62.3575
# 6     9454                    693             1            6.5
# 7    12519                    700             4          57.77
# 8    91179                    633             1      39.990002
# 9    55783                    578             7      82.275714
#
# [10 rows x 4 columns]

# %%
predictions_df.head(10)
# Out:
# Query job 2431ff05-c4b8-4244-819c-3740c7731a5d is DONE. 62.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:2431ff05-c4b8-4244-819c-3740c7731a5d&page=queryresults">Open Job</a>
# Query job a793674e-1bd7-4251-bb4c-ef2c86dfea92 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:a793674e-1bd7-4251-bb4c-ef2c86dfea92&page=queryresults">Open Job</a>
# Query job 375d822c-4f9f-44e1-a2b9-57f947bf76eb is DONE. 1.9 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=qwiklabs-gcp-03-770d1d1bc897&j=bq:US:375d822c-4f9f-44e1-a2b9-57f947bf76eb&page=queryresults">Open Job</a>
#    CENTROID_ID                         NEAREST_CENTROIDS_DISTANCE  \
# 0            3  [{'CENTROID_ID': 3, 'DISTANCE': 0.366734437469...
# 1            4  [{'CENTROID_ID': 4, 'DISTANCE': 0.444748439339...
# 2            2  [{'CENTROID_ID': 2, 'DISTANCE': 1.437399570956...
# 3            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.088371772681...
# 4            4  [{'CENTROID_ID': 4, 'DISTANCE': 0.753915336265...
# 5            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.193884383458...
# 6            5  [{'CENTROID_ID': 5, 'DISTANCE': 1.811468871650...
# 7            4  [{'CENTROID_ID': 4, 'DISTANCE': 1.035959788347...
# 8            1  [{'CENTROID_ID': 1, 'DISTANCE': 0.675342653565...
# 9            2  [{'CENTROID_ID': 2, 'DISTANCE': 1.280205429269...
#
#                                species     island  culmen_length_mm  \
# 0    Gentoo penguin (Pygoscelis papua)     Biscoe              50.5
# 1    Gentoo penguin (Pygoscelis papua)     Biscoe              45.1
# 2  Adelie Penguin (Pygoscelis adeliae)  Torgersen              41.4
# 3  Adelie Penguin (Pygoscelis adeliae)  Torgersen              38.6
# 4    Gentoo penguin (Pygoscelis papua)     Biscoe              46.5
# 5  Adelie Penguin (Pygoscelis adeliae)     Biscoe              35.0
# 6  Adelie Penguin (Pygoscelis adeliae)      Dream              37.5
# 7    Gentoo penguin (Pygoscelis papua)     Biscoe              42.0
# 8    Gentoo penguin (Pygoscelis papua)     Biscoe              48.5
# 9  Adelie Penguin (Pygoscelis adeliae)  Torgersen              45.8
#
#    culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 0             15.9              225.0       5400.0    MALE
# 1             14.5              215.0       5000.0  FEMALE
# 2             18.5              202.0       3875.0    MALE
# 3             17.0              188.0       2900.0  FEMALE
# 4             14.8              217.0       5200.0  FEMALE
# 5             17.9              192.0       3725.0  FEMALE
# 6             18.9              179.0       2975.0    <NA>
# 7             13.5              210.0       4150.0  FEMALE
# 8             14.1              220.0       5300.0    MALE
# 9             18.9              197.0       4150.0    MALE
#
# [10 rows x 9 columns]

# %%
# prompt: 1. Using predictions_df, and matplotlib, generate a scatterplot. 2. On the x-axis of the scatterplot, display days_since_last_order and on the y-axis, display average_spend from predictions_df. 3. Color by cluster. The chart should be titled "Attribute grouped by K-means cluster."


import matplotlib.pyplot as plt

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(predictions_df['days_since_last_order'], predictions_df['average_spend'], c=predictions_df['cluster_id'], cmap='viridis')
plt.xlabel('Days Since Last Order')
plt.ylabel('Average Spend')
plt.title('Attribute grouped by K-means cluster')
plt.colorbar(label='Cluster ID')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5ec7541bda5f> in <cell line: 8>()
#       6 # Create the scatter plot
#       7 plt.figure(figsize=(10, 6))
# ----> 8 plt.scatter(predictions_df['days_since_last_order'], predictions_df['average_spend'], c=predictions_df['cluster_id'], cmap='viridis')
#       9 plt.xlabel('Days Since Last Order')
#      10 plt.ylabel('Average Spend')
#
# /usr/local/lib/python3.10/dist-packages/bigframes/core/log_adapter.py in wrapper(*args, **kwargs)
#      54
#      55         try:
# ---> 56             return method(*args, **kwargs)
#      57         finally:
#      58             _call_stack.pop()
#
# /usr/local/lib/python3.10/dist-packages/bigframes/dataframe.py in __getitem__(self, key)
#     511
#     512         if isinstance(key, typing.Hashable):
# --> 513             return self._getitem_label(key)
#     514         # Select a subset of columns or re-order columns.
#     515         # In Ibis after you apply a projection, any column objects from the
#
# /usr/local/lib/python3.10/dist-packages/bigframes/core/log_adapter.py in wrapper(*args, **kwargs)
#      54
#      55         try:
# ---> 56             return method(*args, **kwargs)
#      57         finally:
#      58             _call_stack.pop()
#
# /usr/local/lib/python3.10/dist-packages/bigframes/dataframe.py in _getitem_label(self, key)
#     540         col_ids = self._block.cols_matching_label(key)
#     541         if len(col_ids) == 0:
# --> 542             raise KeyError(key)
#     543         block = self._block.select_columns(col_ids)
#     544         if isinstance(self.columns, pandas.MultiIndex):
#
# KeyError: 'days_since_last_order'

# %%
query = """
SELECT
 CONCAT('cluster ', CAST(centroid_id as STRING)) as centroid,
 average_spend,
 count_orders,
 days_since_last_order
FROM (
 SELECT centroid_id, feature, ROUND(numerical_value, 2) as value
 FROM ML.CENTROIDS(MODEL `{0}.{1}`)
)
PIVOT (
 SUM(value)
 FOR feature IN ('average_spend',  'count_orders', 'days_since_last_order')
)
ORDER BY centroid_id
""".format(dataset_name, model_name)

df_centroid = client.query(query).to_dataframe()
df_centroid.head()
# Out:
#     centroid  average_spend  count_orders  days_since_last_order
# 0  cluster 1            NaN           NaN                    NaN
# 1  cluster 2            NaN           NaN                    NaN
# 2  cluster 3            NaN           NaN                    NaN
# 3  cluster 4            NaN           NaN                    NaN
# 4  cluster 5            NaN           NaN                    NaN

# %%
df_query = client.query(query).to_dataframe()
df_query.to_string(header=False, index=False)

cluster_info = []
for i, row in df_query.iterrows():
 cluster_info.append("{0}, average spend ${2}, count of orders per person {1}, days since last order {3}"
  .format(row["centroid"], row["count_orders"], row["average_spend"], row["days_since_last_order"]) )

cluster_info = (str.join("\n", cluster_info))
print(cluster_info)
# Out:
# cluster 1, average spend $nan, count of orders per person nan, days since last order nan
# cluster 2, average spend $nan, count of orders per person nan, days since last order nan
# cluster 3, average spend $nan, count of orders per person nan, days since last order nan
# cluster 4, average spend $nan, count of orders per person nan, days since last order nan
# cluster 5, average spend $nan, count of orders per person nan, days since last order nan

# %%
prompt = f"""
You're a creative brand strategist, given the following clusters, come up with \
creative brand persona, a catchy title, and next marketing action, \
explained step by step.

Clusters:
{cluster_info}

For each Cluster:
* Title:
* Persona:
* Next marketing step:
"""

# %%
#prompt:  Use the Vertex AI language_models API to call the PaLM2 text-bison model and generate a marketing campaign using the variable prompt. Use the following model settings: max_output_tokens=1024, temperature=0.4

model = TextGenerationModel.from_pretrained("text-bison")
response = model.predict(prompt, max_output_tokens=1024, temperature=0.4)
print(response.text)
# Out:
#  **Cluster 1: "The Loyalists"**
#
# * **Persona:** These customers are your brand's biggest fans. They love your products and services, and they're always eager to try new things from you. They're also very loyal, and they're likely to stick with your brand for the long haul.
# * **Next marketing step:** Show your appreciation for these customers by offering them exclusive discounts, early access to new products, and other special perks. You can also create a loyalty program that rewards them for their continued business.
#
# **Cluster 2: "The Bargain Hunters"**
#
# * **Persona:** These customers are always looking for a good deal. They're not as brand-loyal as the Loyalists, and they're more likely to switch to a competitor if they find a better price.
# * **Next marketing step:** Offer these customers discounts, coupons, and other promotions to entice them to buy from you. You can also highlight the value of your products and services, and explain why they're worth the price.
#
# **Cluster 3: "The Impulsives"**
#
# * **Persona:** These customers are spontaneous shoppers who are often driven by impulse. They're more likely to buy something if they see it on sale or if it's something new and exciting.
# * **Next marketing step:** Create a sense of urgency and excitement around your products and services. Use social media, email marketing, and other channels to promote your latest offerings and encourage customers to buy now.
#
# **Cluster 4: "The Thoughtfuls"**
#
# * **Persona:** These customers are careful shoppers who do their research before they buy. They're more likely to read reviews, compare prices, and consider the pros and cons of different products before making a decision.
# * **Next marketing step:** Provide these customers with detailed information about your products and services. Make sure your website is informative and easy to navigate, and offer customer reviews and testimonials. You can also run educational campaigns that help customers understand the benefits of your offerings.
#
# **Cluster 5: "The Lapsed Customers"**
#
# * **Persona:** These customers have purchased from you in the past, but they haven't made a purchase in a while. They may have forgotten about your brand, or they may have found a better deal elsewhere.
# * **Next marketing step:** Reach out to these customers with a personalized email or direct mail campaign. Remind them of your brand and your products, and offer them a special incentive to come back. You can also create a win-back campaign that offers discounts or other promotions to lapsed customers.
